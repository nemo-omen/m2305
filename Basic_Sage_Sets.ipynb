# %%
L1=[3,6,9,0,3]

# %%
L2=[9,6,3,0,9]

# %%
[L1==L2, Set(L1)==Set(L2)]
# Out:
# [False, True]

# %%
a = [1,2,3,4,5]

# %%
Set(a)
# Out:
# {1, 2, 3, 4, 5}

# %%
b = Set([1,2,3,4,5])

# %%
b == a
# Out:
# False

# %%
b == Set(a)
# Out:
# True

# %%
c = {1,2,3,4,5}

# %%
b == c
# Out:
# True

# %% [markdown]
# Okay, so we've learned a couple of things about SageMath. First, is that you can denote a list with square brackets, like `[1,2,3,4,5]`
#
# Second, is that you can make a set by instantiating one using `Set()`.

# %%
d = [1,2,3,4,5]

# %%
e = Set(d)

# %%
e == b
# Out:
# True

# %% [markdown]
# Third, you can instantiate a set using a list as a parameter in the set's constructor call, as in cell 13 & a4 above.

# %% [markdown]
# Fourth, you can also take the easy way and define a set the same way you would on paper, using curly braces
#
# ```sage
# c = {1,2,3,4,5}
# ```

# %% [markdown]
# So, all of these things are the same:
# ```sagemath
# a = [1,2,3,4,5] //given this list
# b = Set(a)
# c = {1,2,3,4,5}
#
# c == b //returns True
# ```

# %% [markdown]
# You can evaluate whether a given value is a member of a set:

# %%
f = {1,2,3,4,5}

# %%
5 in f
# Out:
# True

# %% [markdown]
# Above, we can see that using `5 in f` yielded `True`. This is essentially the same as $5 \in f$

# %% [markdown]
# Of course, if I were writing things correctly, my variable name would be `F` so the mathematical expression would be $5 \in F$

# %% [markdown]
# Going forward, it might make sense to take math notes in these notebooks for the ability to evaluate expressions and to represent them with proper notation in the same place.
#
# More than that, though, I'm already using an editor I'm comfortable with. I wonder if there's an extension that will allow me to link to other notebook pages.
